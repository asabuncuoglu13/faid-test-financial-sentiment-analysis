# %% [markdown]
# # Analyse FinBERT using LIT
#
# To analyse the FinBERT model using the Language Interpretability Tool (LIT), you would need to integrate the model into LIT's environment, allowing you to interactively explore its behavior, interpret predictions, and test for fairness, robustness, and other aspects.

# %%
from lit_nlp.api import model as lit_model
from lit_nlp.api import dataset as lit_dataset
from lit_nlp.api import types as lit_types
from lit_nlp import notebook
from transformers import BertTokenizer, BertForSequenceClassification, BertConfig, pipeline
import pandas as pd
import torch

# %% [markdown]
# You'll need to load the FinBERT model within a custom model class that LIT can recognize.

# %%
class FinBERTModel(lit_model.Model):
    """A wrapper for FinBERT to work with LIT."""
    
    def __init__(self):
        # Load FinBERT model and tokenizer
        self.model_name = "yiyanghkust/finbert-tone"
        self.model = BertForSequenceClassification.from_pretrained(self.model_name, num_labels=3)
        self.tokenizer = BertTokenizer.from_pretrained(self.model_name)
        self.config = BertConfig.from_pretrained(self.model_name)

    def _load_model(self):
        return BertForSequenceClassification.from_pretrained(self.model_name, num_labels=3)
    
    def _load_tokenizer(self):
        return BertTokenizer.from_pretrained(self.model_name)
        
    def input_spec(self) -> lit_types.Spec:
        return {
            "text": lit_types.TextSegment()
        }
    
    def output_spec(self) -> lit_types.Spec:
        return {
            "score": lit_types.MulticlassPreds(vocab=["Positive", "Neutral", "Negative"], parent="label"),
            "label": lit_types.CategoryLabel(vocab=["Positive", "Neutral", "Negative"]),
        }
    
    def predict(self, inputs):
        # create a list of strings from the input
        # input_list = []
        results = []
        for input in inputs:
            # input_list.append(input["text"])
            
            # if you don't want to use the pipeline, you can use the model directly
            with torch.no_grad():
                encoded_input = self.tokenizer(input["text"], padding=True, return_tensors='pt')
                output = self.model(**encoded_input)
                probs = torch.softmax(output['logits'], dim=1)
                label = self.config.id2label[torch.argmax(probs).item()]
                results.append({
                    "score": probs[0].tolist(),
                    "label": label
                })

        # pipe = pipeline("text-classification", model=self.model, tokenizer=self.tokenizer)
        # results = pipe(input_list)
        return results

# Instantiate the FinBERT model
model = FinBERTModel()
# Out:
# /Users/asabuncuoglu/Documents/faid-test-financial-sentiment-analysis/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
class FinDataset(lit_dataset.Dataset):
  """Loader for MultiNLI development set."""

  TEXT_COLUMN = "text"
  TARGET_COLUMN = "sentiment"

  def __init__(self, path: str):
    df = pd.read_csv(path, names=[self.TARGET_COLUMN, self.TEXT_COLUMN], encoding="utf-8", encoding_errors="replace")
    # Store as a list of dicts, conforming to self.spec()
    df = df.head(20) # limit to 20 examples for speed
    self._examples = pd.DataFrame.to_dict(df, orient="records")

  def spec(self) -> lit_types.Spec:
    return {
      'text': lit_types.TextSegment(),
      'sentiment': lit_types.CategoryLabel(vocab=["Positive", "Neutral", "Negative"])
    }

# %%
class IndianDataset(lit_dataset.Dataset):
  """Loader for MultiNLI development set."""

  TEXT_COLUMN = "Summary"
  TARGET_COLUMN = "Sentiment"

  def __init__(self):
    # Download the dataset directly from Huggingface
    df =  pd.read_csv("hf://datasets/kdave/Indian_Financial_News/training_data_26000.csv", names=[self.TEXT_COLUMN, self.TARGET_COLUMN])
    # change the TEXT_COLUMN name to "text" and TARGET_COLUMN name to "sentiment"
    df = df.rename(columns={self.TEXT_COLUMN: "text", self.TARGET_COLUMN: "sentiment"})
    df = df.head(350) # limit to 350 examples for speed
    self._examples = pd.DataFrame.to_dict(df, orient="records")

  def spec(self) -> lit_types.Spec:
    return {
      'text': lit_types.TextSegment(),
      'sentiment': lit_types.CategoryLabel(vocab=["Positive", "Neutral", "Negative"])
    }

# %% [markdown]
# After wrapping the FinBERT model, you need to launch the LIT server to interactively analyze the model.

# %%
#filename = "../data/external/financialphrasebank.csv"
filename = "../data/external/indian_news.csv"

# Initialize dataset and model
#dataset = FinDataset(path=filename)
dataset = IndianDataset()
model = FinBERTModel()

# Create the LIT widget
lit_widget = notebook.LitWidget(models={"model": model}, datasets={"data": dataset}, port=8890)
#lit_widget.render()
# Out:
# /Users/asabuncuoglu/Documents/faid-test-financial-sentiment-analysis/.venv/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# WARNING:absl:Unable to infer init spec for dataset 'NoneDataset'. Unable to infer a type for parameter 'models' of '__init__'. Please add a type hint or default value, or implement a Spec literal.
# 127.0.0.1 - - [20/Sep/2024 11:31:05] "GET / HTTP/1.1" 200 1408
# 127.0.0.1 - - [20/Sep/2024 11:31:05] "GET /main.js HTTP/1.1" 200 2024211
# 127.0.0.1 - - [20/Sep/2024 11:31:05] "GET /static/favicon.png HTTP/1.1" 200 13257
# 127.0.0.1 - - [20/Sep/2024 11:31:05] "POST /get_info? HTTP/1.1" 200 24140
# 127.0.0.1 - - [20/Sep/2024 11:31:05] "POST /get_dataset?dataset_name=data HTTP/1.1" 200 216542
# 127.0.0.1 - - [20/Sep/2024 11:31:05] "GET /static/onboarding_1_welcome.gif HTTP/1.1" 200 584363
# 127.0.0.1 - - [20/Sep/2024 11:31:22] "POST /get_interpretations?model=model&dataset_name=data&interpreter=classification&do_predict=1 HTTP/1.1" 200 67786
# 127.0.0.1 - - [20/Sep/2024 11:31:22] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:31:22] "POST /get_metrics?model=model&dataset_name=data&metrics=multiclass,paired&do_predict=1 HTTP/1.1" 200 32
# 127.0.0.1 - - [20/Sep/2024 11:31:22] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:31:27] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:31:35] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:31:43] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:31:51] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:31:52] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:02] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:03] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:04] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:10] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:10] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:11] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:12] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:13] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:14] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:15] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:17] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:18] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:18] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:24] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:24] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:27] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:27] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:29] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:30] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:31] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:34] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:35] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:46] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:50] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:50] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:57] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:58] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:59] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:32:59] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:00] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:02] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:03] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:05] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:05] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:08] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:09] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:09] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:10] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:11] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:12] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:13] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:13] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:14] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:33:26] "POST /get_preds?model=model&dataset_name=data&requested_types=MulticlassPreds,RegressionScore&requested_fields= HTTP/1.1" 200 80
# WARNING:absl:Attmepting to retrieve 1 (of 1) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# WARNING:absl:Attmepting to retrieve 257 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:34:10] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 1704
# 127.0.0.1 - - [20/Sep/2024 11:34:10] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:34:13] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:34:14] "POST /get_preds?model=model&dataset_name=data&requested_types=MulticlassPreds,RegressionScore&requested_fields= HTTP/1.1" 200 80
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:34:24] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 1698
# WARNING:absl:Attmepting to retrieve 1 (of 1) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# WARNING:absl:Attmepting to retrieve 257 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:34:35] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 1697
# 127.0.0.1 - - [20/Sep/2024 11:34:35] "POST /get_metrics?model=model&dataset_name=data&metrics=multiclass,paired&do_predict=1 HTTP/1.1" 200 32
# 127.0.0.1 - - [20/Sep/2024 11:35:09] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:35:11] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:35:12] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:35:18] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:35:23] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:35:25] "POST /get_preds?model=model&dataset_name=data&requested_types=MulticlassPreds,RegressionScore&requested_fields= HTTP/1.1" 200 79
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:35:35] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 1676
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:35:46] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 1677
# WARNING:absl:Attmepting to retrieve 1 (of 1) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# WARNING:absl:Attmepting to retrieve 257 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:35:57] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 1674
# 127.0.0.1 - - [20/Sep/2024 11:36:49] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:36:50] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:36:53] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:36:54] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:36:58] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:36:58] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:36:59] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:36:59] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:37:00] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:37:04] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:37:08] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:37:09] "POST /get_preds?model=model&dataset_name=data&requested_types=MulticlassPreds,RegressionScore&requested_fields= HTTP/1.1" 200 80
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:37:20] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 1709
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:37:30] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 1699
# WARNING:absl:Attmepting to retrieve 1 (of 1) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# WARNING:absl:Attmepting to retrieve 257 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:37:42] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 1697
# 127.0.0.1 - - [20/Sep/2024 11:37:42] "GET /static/potato.svg HTTP/1.1" 200 3717
# 127.0.0.1 - - [20/Sep/2024 11:37:42] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:37:42] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:37:42] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:37:42] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:37:42] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:37:42] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:37:42] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:37:42] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:37:42] "POST /get_preds?model=model&dataset_name=data&requested_types=MulticlassPreds,RegressionScore&requested_fields= HTTP/1.1" 200 80
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:37:53] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 2014
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:38:04] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 2013
# WARNING:absl:Attmepting to retrieve 1 (of 1) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# WARNING:absl:Attmepting to retrieve 257 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:38:16] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 2004
# 127.0.0.1 - - [20/Sep/2024 11:38:16] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:38:16] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:38:17] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:38:18] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:38:19] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:38:19] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:38:20] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:53:10] "POST /get_preds?model=model&dataset_name=data&requested_types=MulticlassPreds,RegressionScore&requested_fields= HTTP/1.1" 200 77
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:53:22] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 2188
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:53:34] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 2192
# WARNING:absl:Attmepting to retrieve 1 (of 1) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# WARNING:absl:Attmepting to retrieve 257 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:53:46] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 2185
# 127.0.0.1 - - [20/Sep/2024 11:53:46] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:53:46] "POST /get_preds?model=model&dataset_name=data&requested_types=MulticlassPreds,RegressionScore&requested_fields= HTTP/1.1" 200 78
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:53:57] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 1783
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:54:08] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 1797
# WARNING:absl:Attmepting to retrieve 1 (of 1) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# WARNING:absl:Attmepting to retrieve 257 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:54:19] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 1789
# 127.0.0.1 - - [20/Sep/2024 11:54:19] "POST /annotate_new_data?dataset_name=data HTTP/1.1" 200 765
# 127.0.0.1 - - [20/Sep/2024 11:54:19] "POST /get_interpretations?model=model&dataset_name=data&interpreter=classification&do_predict=1 HTTP/1.1" 200 67987
# 127.0.0.1 - - [20/Sep/2024 11:54:19] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:54:19] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:54:19] "POST /get_preds?model=model&dataset_name=data&requested_types=MulticlassPreds,RegressionScore&requested_fields= HTTP/1.1" 200 80
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:54:31] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 2242
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:54:44] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 2242
# WARNING:absl:Attmepting to retrieve 1 (of 1) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# WARNING:absl:Attmepting to retrieve 257 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:54:56] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 2245
# 127.0.0.1 - - [20/Sep/2024 11:54:56] "GET /static/onboarding_2_modules.gif HTTP/1.1" 200 671030
# 127.0.0.1 - - [20/Sep/2024 11:54:56] "GET /static/onboarding_3_workspaces.gif HTTP/1.1" 200 1588717
# 127.0.0.1 - - [20/Sep/2024 11:54:56] "GET /static/onboarding_4_explore.gif HTTP/1.1" 200 380277
# 127.0.0.1 - - [20/Sep/2024 11:54:56] "POST /annotate_new_data?dataset_name=data HTTP/1.1" 200 764
# 127.0.0.1 - - [20/Sep/2024 11:54:56] "POST /get_interpretations?model=model&dataset_name=data&interpreter=classification&do_predict=1 HTTP/1.1" 200 68187
# 127.0.0.1 - - [20/Sep/2024 11:54:56] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:54:56] "POST /push_ui_state?dataset_name=data HTTP/1.1" 200 4
# 127.0.0.1 - - [20/Sep/2024 11:54:56] "POST /get_preds?model=model&dataset_name=data&requested_types=MulticlassPreds,RegressionScore&requested_fields= HTTP/1.1" 200 79
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:55:08] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 2220
# WARNING:absl:Attmepting to retrieve 256 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:55:20] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 2212
# WARNING:absl:Attmepting to retrieve 1 (of 1) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# WARNING:absl:Attmepting to retrieve 257 (of 257) predictions from the cache where the cache key is None - this can be from a missing or empty example id. These will call model.predict() on this and subsequent calls.
# 127.0.0.1 - - [20/Sep/2024 11:55:31] "POST /get_interpretations?model=model&dataset_name=data&interpreter=LIME&do_predict=1 HTTP/1.1" 200 2214

# %% [markdown]
# Once the server is running, you can access LIT in your web browser by navigating to `http://localhost:8890`. Or optionally, you can run it on your notebook:
#
# ```python
# widget.render(height=600)
# ```
#
# Note that, I could not run this widget on VSCode's Jupyter Notebook Editor, so I only tested the functionality on the browser. In the LIT interface, you can interactively explore the model's predictions, compare different inputs, visualize feature importance, and analyze model behavior through various interpretability techniques.
#
# ### Analyze Model Behavior
# - **Examine Predictions**: Input different financial texts and observe how FinBERT classifies the sentiment. You can compare results across multiple texts or even multiple models if loaded.
# - **Saliency Maps**: Use saliency maps to understand which words contribute most to the sentiment classification.
# - **Counterfactuals**: Test counterfactual scenarios by modifying parts of the text to see how the model’s prediction changes, helping you understand its decision-making process.
# - **Fairness Analysis**: Analyze how the model performs across different types of financial data (e.g., news articles about different industries or regions) to check for any biases.
#
# This setup enables you to ensure the model’s fairness, understand its decision-making process, and refine its performance for financial sentiment analysis.
