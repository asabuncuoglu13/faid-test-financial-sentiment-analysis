# %%
import stanza

# We tested here Stanza, but alternatively we could use Spacy, NLTK, or trankit
# See performance benchmark of these tools here: https://trankit.readthedocs.io/en/latest/performance.html#universal-dependencies-v2-5

# %% [markdown]
# See NER entity explanations here: <https://dataknowsall.com/blog/ner.html>
#
# ```
# PERSON:      People, including fictional.
# NORP:        Nationalities or religious or political groups.
# FAC:         Buildings, airports, highways, bridges, etc.
# ORG:         Companies, agencies, institutions, etc.
# GPE:         Countries, cities, states.
# LOC:         Non-GPE locations, mountain ranges, bodies of water.
# PRODUCT:     Objects, vehicles, foods, etc. (Not services.)
# EVENT:       Named hurricanes, battles, wars, sports events, etc.
# WORK_OF_ART: Titles of books, songs, etc.
# LAW:         Named documents made into laws.
# LANGUAGE:    Any named language.
# DATE:        Absolute or relative dates or periods.
# TIME:        Times smaller than a day.
# PERCENT:     Percentage, including ”%“.
# MONEY:       Monetary values, including unit.
# QUANTITY:    Measurements, as of weight or distance.
# ORDINAL:     “first”, “second”, etc.
# CARDINAL:    Numerals that do not fall under another type.
# ```

# %%
stanza.download('en')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-09-17 09:56:56 INFO: Downloaded file to /Users/asabuncuoglu/stanza_resources/resources.json
# 2024-09-17 09:56:56 INFO: Downloading default packages for language: en (English) ...
# 2024-09-17 09:56:58 INFO: File exists: /Users/asabuncuoglu/stanza_resources/en/default.zip
# 2024-09-17 09:57:00 INFO: Finished downloading models and saved to /Users/asabuncuoglu/stanza_resources

# %%
nlp = stanza.Pipeline('en')
# Out:
# 2024-09-17 09:57:00 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-09-17 09:57:00 INFO: Downloaded file to /Users/asabuncuoglu/stanza_resources/resources.json
# 2024-09-17 09:57:02 INFO: Loading these models for language: en (English):
# ============================================
# | Processor    | Package                   |
# --------------------------------------------
# | tokenize     | combined                  |
# | mwt          | combined                  |
# | pos          | combined_charlm           |
# | lemma        | combined_nocharlm         |
# | constituency | ptb3-revised_charlm       |
# | depparse     | combined_charlm           |
# | sentiment    | sstplus_charlm            |
# | ner          | ontonotes-ww-multi_charlm |
# ============================================
#
# 2024-09-17 09:57:02 INFO: Using device: cpu
# 2024-09-17 09:57:02 INFO: Loading: tokenize
# 2024-09-17 09:57:03 INFO: Loading: mwt
# 2024-09-17 09:57:03 INFO: Loading: pos
# 2024-09-17 09:57:03 INFO: Loading: lemma
# 2024-09-17 09:57:03 INFO: Loading: constituency
# 2024-09-17 09:57:03 INFO: Loading: depparse
# 2024-09-17 09:57:04 INFO: Loading: sentiment
# 2024-09-17 09:57:04 INFO: Loading: ner
# 2024-09-17 09:57:04 INFO: Done loading processors!

# %%
doc = nlp("new car registrations collapsed by a 'precipitous' 97 percent last month. decline is in line with similar falls across Europe. many showrooms were closed for the coronavirus lockdown. around 1.68 million new cars will be registered in 2020. the lockdown was implemented nationwide on march 23. a strong new car market supports a healthy economy.")
doc
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "new",
#       "lemma": "new",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 3,
#       "deprel": "amod",
#       "start_char": 0,
#       "end_char": 3,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "car",
#       "lemma": "car",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "compound",
#       "start_char": 4,
#       "end_char": 7,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "registrations",
#       "lemma": "registration",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 4,
#       "deprel": "nsubj",
#       "start_char": 8,
#       "end_char": 21,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "collapsed",
#       "lemma": "collapse",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 22,
#       "end_char": 31,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "by",
#       "lemma": "by",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 11,
#       "deprel": "case",
#       "start_char": 32,
#       "end_char": 34,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "head": 11,
#       "deprel": "det",
#       "start_char": 35,
#       "end_char": 36,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "'",
#       "lemma": "'",
#       "upos": "PUNCT",
#       "xpos": "``",
#       "head": 8,
#       "deprel": "punct",
#       "start_char": 37,
#       "end_char": 38,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ],
#       "misc": "SpaceAfter=No"
#     },
#     {
#       "id": 8,
#       "text": "precipitous",
#       "lemma": "precipitous",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 11,
#       "deprel": "amod",
#       "start_char": 38,
#       "end_char": 49,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ],
#       "misc": "SpaceAfter=No"
#     },
#     {
#       "id": 9,
#       "text": "'",
#       "lemma": "'",
#       "upos": "PUNCT",
#       "xpos": "''",
#       "head": 8,
#       "deprel": "punct",
#       "start_char": 49,
#       "end_char": 50,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "97",
#       "lemma": "97",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 11,
#       "deprel": "nummod",
#       "start_char": 51,
#       "end_char": 53,
#       "ner": "B-PERCENT",
#       "multi_ner": [
#         "B-PERCENT"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "percent",
#       "lemma": "percent",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 4,
#       "deprel": "obl",
#       "start_char": 54,
#       "end_char": 61,
#       "ner": "E-PERCENT",
#       "multi_ner": [
#         "E-PERCENT"
#       ]
#     },
#     {
#       "id": 12,
#       "text": "last",
#       "lemma": "last",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 13,
#       "deprel": "amod",
#       "start_char": 62,
#       "end_char": 66,
#       "ner": "B-DATE",
#       "multi_ner": [
#         "B-DATE"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "month",
#       "lemma": "month",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 4,
#       "deprel": "obl:tmod",
#       "start_char": 67,
#       "end_char": 72,
#       "ner": "E-DATE",
#       "multi_ner": [
#         "E-DATE"
#       ],
#       "misc": "SpaceAfter=No"
#     },
#     {
#       "id": 14,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 4,
#       "deprel": "punct",
#       "start_char": 72,
#       "end_char": 73,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "decline",
#       "lemma": "decline",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 4,
#       "deprel": "nsubj",
#       "start_char": 74,
#       "end_char": 81,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "is",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 4,
#       "deprel": "cop",
#       "start_char": 82,
#       "end_char": 84,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 4,
#       "deprel": "case",
#       "start_char": 85,
#       "end_char": 87,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "line",
#       "lemma": "line",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 88,
#       "end_char": 92,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "with",
#       "lemma": "with",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 7,
#       "deprel": "case",
#       "start_char": 93,
#       "end_char": 97,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "similar",
#       "lemma": "similar",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 7,
#       "deprel": "amod",
#       "start_char": 98,
#       "end_char": 105,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "falls",
#       "lemma": "falls",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 4,
#       "deprel": "nmod",
#       "start_char": 106,
#       "end_char": 111,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "across",
#       "lemma": "across",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 9,
#       "deprel": "case",
#       "start_char": 112,
#       "end_char": 118,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "Europe",
#       "lemma": "Europe",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 7,
#       "deprel": "nmod",
#       "start_char": 119,
#       "end_char": 125,
#       "ner": "S-LOC",
#       "multi_ner": [
#         "S-LOC"
#       ],
#       "misc": "SpaceAfter=No"
#     },
#     {
#       "id": 10,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 4,
#       "deprel": "punct",
#       "start_char": 125,
#       "end_char": 126,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "many",
#       "lemma": "many",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 2,
#       "deprel": "amod",
#       "start_char": 127,
#       "end_char": 131,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "showrooms",
#       "lemma": "showroom",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 4,
#       "deprel": "nsubj",
#       "start_char": 132,
#       "end_char": 141,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "were",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin",
#       "head": 4,
#       "deprel": "cop",
#       "start_char": 142,
#       "end_char": 146,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "closed",
#       "lemma": "close",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 147,
#       "end_char": 153,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "for",
#       "lemma": "for",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 8,
#       "deprel": "case",
#       "start_char": 154,
#       "end_char": 157,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 8,
#       "deprel": "det",
#       "start_char": 158,
#       "end_char": 161,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "coronavirus",
#       "lemma": "coronavirus",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "compound",
#       "start_char": 162,
#       "end_char": 173,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "lockdown",
#       "lemma": "lockdown",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 4,
#       "deprel": "obl",
#       "start_char": 174,
#       "end_char": 182,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ],
#       "misc": "SpaceAfter=No"
#     },
#     {
#       "id": 9,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 4,
#       "deprel": "punct",
#       "start_char": 182,
#       "end_char": 183,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "around",
#       "lemma": "around",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 3,
#       "deprel": "advmod",
#       "start_char": 184,
#       "end_char": 190,
#       "ner": "B-CARDINAL",
#       "multi_ner": [
#         "B-CARDINAL"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "1.68",
#       "lemma": "1.68",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Frac",
#       "head": 3,
#       "deprel": "compound",
#       "start_char": 191,
#       "end_char": 195,
#       "ner": "I-CARDINAL",
#       "multi_ner": [
#         "I-CARDINAL"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "million",
#       "lemma": "million",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 5,
#       "deprel": "nummod",
#       "start_char": 196,
#       "end_char": 203,
#       "ner": "E-CARDINAL",
#       "multi_ner": [
#         "E-CARDINAL"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "new",
#       "lemma": "new",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 5,
#       "deprel": "amod",
#       "start_char": 204,
#       "end_char": 207,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "cars",
#       "lemma": "car",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 8,
#       "deprel": "nsubj:pass",
#       "start_char": 208,
#       "end_char": 212,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "will",
#       "lemma": "will",
#       "upos": "AUX",
#       "xpos": "MD",
#       "feats": "VerbForm=Fin",
#       "head": 8,
#       "deprel": "aux",
#       "start_char": 213,
#       "end_char": 217,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "be",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 8,
#       "deprel": "aux:pass",
#       "start_char": 218,
#       "end_char": 220,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "registered",
#       "lemma": "register",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 221,
#       "end_char": 231,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "in",
#       "lemma": "in",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 10,
#       "deprel": "case",
#       "start_char": 232,
#       "end_char": 234,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "2020",
#       "lemma": "2020",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 8,
#       "deprel": "obl",
#       "start_char": 235,
#       "end_char": 239,
#       "ner": "S-DATE",
#       "multi_ner": [
#         "S-DATE"
#       ],
#       "misc": "SpaceAfter=No"
#     },
#     {
#       "id": 11,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 8,
#       "deprel": "punct",
#       "start_char": 239,
#       "end_char": 240,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "the",
#       "lemma": "the",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Def|PronType=Art",
#       "head": 2,
#       "deprel": "det",
#       "start_char": 241,
#       "end_char": 244,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "lockdown",
#       "lemma": "lockdown",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 4,
#       "deprel": "nsubj:pass",
#       "start_char": 245,
#       "end_char": 253,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "was",
#       "lemma": "be",
#       "upos": "AUX",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "head": 4,
#       "deprel": "aux:pass",
#       "start_char": 254,
#       "end_char": 257,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "implemented",
#       "lemma": "implement",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 258,
#       "end_char": 269,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "nationwide",
#       "lemma": "nationwide",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 4,
#       "deprel": "advmod",
#       "start_char": 270,
#       "end_char": 280,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "on",
#       "lemma": "on",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 7,
#       "deprel": "case",
#       "start_char": 281,
#       "end_char": 283,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "march",
#       "lemma": "march",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 4,
#       "deprel": "obl",
#       "start_char": 284,
#       "end_char": 289,
#       "ner": "B-DATE",
#       "multi_ner": [
#         "B-DATE"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "23",
#       "lemma": "23",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 7,
#       "deprel": "nummod",
#       "start_char": 290,
#       "end_char": 292,
#       "ner": "E-DATE",
#       "multi_ner": [
#         "E-DATE"
#       ],
#       "misc": "SpaceAfter=No"
#     },
#     {
#       "id": 9,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 4,
#       "deprel": "punct",
#       "start_char": 292,
#       "end_char": 293,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "head": 5,
#       "deprel": "det",
#       "start_char": 294,
#       "end_char": 295,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "strong",
#       "lemma": "strong",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 5,
#       "deprel": "amod",
#       "start_char": 296,
#       "end_char": 302,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "new",
#       "lemma": "new",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 5,
#       "deprel": "amod",
#       "start_char": 303,
#       "end_char": 306,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "car",
#       "lemma": "car",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 5,
#       "deprel": "compound",
#       "start_char": 307,
#       "end_char": 310,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "market",
#       "lemma": "market",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "nsubj",
#       "start_char": 311,
#       "end_char": 317,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "supports",
#       "lemma": "support",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 318,
#       "end_char": 326,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "a",
#       "lemma": "a",
#       "upos": "DET",
#       "xpos": "DT",
#       "feats": "Definite=Ind|PronType=Art",
#       "head": 9,
#       "deprel": "det",
#       "start_char": 327,
#       "end_char": 328,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "healthy",
#       "lemma": "healthy",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 9,
#       "deprel": "amod",
#       "start_char": 329,
#       "end_char": 336,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "economy",
#       "lemma": "economy",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "obj",
#       "start_char": 337,
#       "end_char": 344,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ],
#       "misc": "SpaceAfter=No"
#     },
#     {
#       "id": 10,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 6,
#       "deprel": "punct",
#       "start_char": 344,
#       "end_char": 345,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ],
#       "misc": "SpaceAfter=No"
#     }
#   ]
# ]

# %%
for ent in doc.ents:
    print(ent.text, ent.type)
# Out:
# 97 percent PERCENT
# last month DATE
# Europe LOC
# around 1.68 million CARDINAL
# 2020 DATE
# march 23 DATE

# %%
# Load the Indian News dataset and extract entities
import pandas as pd
df = pd.read_csv("../../data/external/indian_news.csv", encoding="utf-8", usecols=["Summary","Sentiment"])
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Load the Indian News dataset and extract entities
#       2 import pandas as pd
# ----> 3 df = pd.read_csv("../../data/external/indian_news.csv", encoding="utf-8", usecols=["Summary","Sentiment"])
#       4 df.head()
#
# File ~/Documents/faid-test-financial-sentiment-analysis/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/faid-test-financial-sentiment-analysis/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Documents/faid-test-financial-sentiment-analysis/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/faid-test-financial-sentiment-analysis/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Documents/faid-test-financial-sentiment-analysis/.venv/lib/python3.10/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/external/indian_news.csv'

# %%
"""
The dataset contains news articles and their sentiment. We will extract entities from the news articles using the NER model. It took around 6 hours to extract entities from all the news articles. We saved the entities to a new CSV file.
"""
"""
df["LOC"] = None
df["ORG"] = None
df["LOC_location"] = None
df["ORG_location"] = None

for i, row in df.iterrows():
    doc = nlp(row["Summary"])
    locs = []
    orgs = []
    locs_start = []
    orgs_start = []
    for ent in doc.ents:
        if ent.type == "LOC":
            locs.append(str(ent.text).lower())
            locs_start.append(ent.start_char)
        if ent.type == "ORG":
            orgs.append(str(ent.text).lower())
            orgs_start.append(ent.start_char)
    
    # Add locs and orgs to the dataframe, use | to separate multiple entities
    if len(orgs) > 0:
        df.at[i, "ORG"] = str(orgs).replace("[","").replace("]","").replace("'","").replace(",","|")
        df.at[i, "ORG_location"] = str(orgs_start).replace("[","").replace("]","").replace("'","").replace(",","|")
    if len(locs) > 0:
        df.at[i, "LOC"] = str(locs).replace("[","").replace("]","").replace("'","").replace(",","|")
        df.at[i, "LOC_location"] = str(locs_start).replace("[","").replace("]","").replace("'","").replace(",","|")

    if (i+1) % 100 == 0:
        print(f"{i+1} news processed")
        #save the dataframe to a csv file
        df.to_csv("../data/processed/indian_news_entities.csv", index=False)
"""
# Out:
# 100 news processed
# 200 news processed
# 300 news processed
# 400 news processed
# 500 news processed
# 600 news processed
# 700 news processed
# 800 news processed
# 900 news processed
# 1000 news processed
# 1100 news processed
# 1200 news processed
# 1300 news processed
# 1400 news processed
# 1500 news processed
# 1600 news processed
# 1700 news processed
# 1800 news processed
# 1900 news processed
# 2000 news processed
# 2100 news processed
# 2200 news processed
# 2300 news processed
# 2400 news processed
# 2500 news processed
# 2600 news processed
# 2700 news processed
# 2800 news processed
# 2900 news processed
# 3000 news processed
# 3100 news processed
# 3200 news processed
# 3300 news processed
# 3400 news processed
# 3500 news processed
# 3600 news processed
# 3700 news processed
# 3800 news processed
# 3900 news processed
# 4000 news processed
# 4100 news processed
# 4200 news processed
# 4300 news processed
# 4400 news processed
# 4500 news processed
# 4600 news processed
# 4700 news processed
# 4800 news processed
# 4900 news processed
# 5000 news processed
# 5100 news processed
# 5200 news processed
# 5300 news processed
# 5400 news processed
# 5500 news processed
# 5600 news processed
# 5700 news processed
# 5800 news processed
# 5900 news processed
# 6000 news processed
# 6100 news processed
# 6200 news processed
# 6300 news processed
# 6400 news processed
# 6500 news processed
# 6600 news processed
# 6700 news processed
# 6800 news processed
# 6900 news processed
# 7000 news processed
# 7100 news processed
# 7200 news processed
# 7300 news processed
# 7400 news processed
# 7500 news processed
# 7600 news processed
# 7700 news processed
# 7800 news processed
# 7900 news processed
# 8000 news processed
# 8100 news processed
# 8200 news processed
# 8300 news processed
# 8400 news processed
# 8500 news processed
# 8600 news processed
# 8700 news processed
# 8800 news processed
# 8900 news processed
# 9000 news processed
# 9100 news processed
# 9200 news processed
# 9300 news processed
# 9400 news processed
# 9500 news processed
# 9600 news processed
# 9700 news processed
# 9800 news processed
# 9900 news processed
# 10000 news processed
# 10100 news processed
# 10200 news processed
# 10300 news processed
# 10400 news processed
# 10500 news processed
# 10600 news processed
# 10700 news processed
# 10800 news processed
# 10900 news processed
# 11000 news processed
# 11100 news processed
# 11200 news processed
# 11300 news processed
# 11400 news processed
# 11500 news processed
# 11600 news processed
# 11700 news processed
# 11800 news processed
# 11900 news processed
# 12000 news processed
# 12100 news processed
# 12200 news processed
# 12300 news processed
# 12400 news processed
# 12500 news processed
# 12600 news processed
# 12700 news processed
# 12800 news processed
# 12900 news processed
# 13000 news processed
# 13100 news processed
# 13200 news processed
# 13300 news processed
# 13400 news processed
# 13500 news processed
# 13600 news processed
# 13700 news processed
# 13800 news processed
# 13900 news processed
# 14000 news processed
# 14100 news processed
# 14200 news processed
# 14300 news processed
# 14400 news processed
# 14500 news processed
# 14600 news processed
# 14700 news processed
# 14800 news processed
# 14900 news processed
# 15000 news processed
# 15100 news processed
# 15200 news processed
# 15300 news processed
# 15400 news processed
# 15500 news processed
# 15600 news processed
# 15700 news processed
# 15800 news processed
# 15900 news processed
# 16000 news processed
# 16100 news processed
# 16200 news processed
# 16300 news processed
# 16400 news processed
# 16500 news processed
# 16600 news processed
# 16700 news processed
# 16800 news processed
# 16900 news processed
# 17000 news processed
# 17100 news processed
# 17200 news processed
# 17300 news processed
# 17400 news processed
# 17500 news processed
# 17600 news processed
# 17700 news processed
# 17800 news processed
# 17900 news processed
# 18000 news processed
# 18100 news processed
# 18200 news processed
# 18300 news processed
# 18400 news processed
# 18500 news processed
# 18600 news processed
# 18700 news processed
# 18800 news processed
# 18900 news processed
# 19000 news processed
# 19100 news processed
# 19200 news processed
# 19300 news processed
# 19400 news processed
# 19500 news processed
# 19600 news processed
# 19700 news processed
# 19800 news processed
# 19900 news processed
# 20000 news processed
# 20100 news processed
# 20200 news processed
# 20300 news processed
# 20400 news processed
# 20500 news processed
# 20600 news processed
# 20700 news processed
# 20800 news processed
# 20900 news processed
# 21000 news processed
# 21100 news processed
# 21200 news processed
# 21300 news processed
# 21400 news processed
# 21500 news processed
# 21600 news processed
# 21700 news processed
# 21800 news processed
# 21900 news processed
# 22000 news processed
# 22100 news processed
# 22200 news processed
# 22300 news processed
# 22400 news processed
# 22500 news processed
# 22600 news processed
# 22700 news processed
# 22800 news processed
# 22900 news processed
# 23000 news processed
# 23100 news processed
# 23200 news processed
# 23300 news processed
# 23400 news processed
# 23500 news processed
# 23600 news processed
# 23700 news processed
# 23800 news processed
# 23900 news processed
# 24000 news processed
# 24100 news processed
# 24200 news processed
# 24300 news processed
# 24400 news processed
# 24500 news processed
# 24600 news processed
# 24700 news processed
# 24800 news processed
# 24900 news processed
# 25000 news processed
# 25100 news processed
# 25200 news processed
# 25300 news processed
# 25400 news processed
# 25500 news processed
# 25600 news processed
# 25700 news processed
# 25800 news processed
# 25900 news processed
# 26000 news processed
# 26100 news processed
# 26200 news processed
# 26300 news processed
# 26400 news processed
# 26500 news processed
# 26600 news processed
# 26700 news processed
# 26800 news processed
# 26900 news processed

# %%
df = pd.read_csv("../../data/processed/indian_news_entities.csv", encoding="utf-8")
df.head()
# Out:
#                                              Summary Sentiment  LOC  \
# 0  consumer spending plunges 13.6 percent in Apri...  Negative  NaN
# 1  government will have to take a bulk of the tab...  Negative  NaN
# 2  exporters are facing issues in terms of raw ma...  Negative  NaN
# 3  the dollar loses some ground on the safe haven...  Negative  NaN
# 4  six Indian public-sector undertakings have tak...  Negative  NaN
#
#                 ORG LOC_location ORG_location
# 0           reuters          NaN          224
# 1  the reserve bank          NaN          327
# 2               NaN          NaN          NaN
# 3               NaN          NaN          NaN
# 4               NaN          NaN          NaN

# %%
# get all the values of no None LOC and ORG
locs = df["LOC"].dropna().values
orgs = df["ORG"].dropna().values

locs = [loc.split("|") for loc in locs]
locs = [item for sublist in locs for item in sublist]
locs = list(set(locs))
print(locs)

orgs = [org.split("|") for org in orgs]
orgs = [item for sublist in orgs for item in sublist]
orgs = list(set(orgs))
print(orgs)
# Out:
# [' covid', ' asia pacific', ' middle east', ' "west bengals it"', ' asia-pacific', 'indus', 'south africa', 'west bengal’s', ' nicobar', 'cyclone amphan', 'brexit', 'the asia-pacific', 'arctic', 'atlantic', 'la nina', 'north america', 'west texas intermediate', '"asia"', 'symmetrical triangle', 'north east india', 'heikin-ashi', 'tier ii', ' the ravi river', '"pakistans narowal"', 'north east', 'kashmir', ' sub-saharan africa', 'asia pacific', 'east ladakh', 'terai', 'the green and orange zones', 'taiwan strait', 'the asia-pacific region', 'the arabian sea', ' union territories', 'andaman & nicobar', ' the falling wedge', ' northern europe', 'coronavirus', 'antarctica', 'renaissance', 'ge’s south asia', 'south korea.', 'the 10220-10230 zone', 'asia-pacific', '"indias southwest coast"', ' central', 'europe', 'middle east', 'the mississippi bubble', 'asia', 'ayushman pakhwaras', ' north america', ' africa', 'lower zakum', ' middle-east', ' green zone', 'greater noida’s', 'middle-east', 'andaman', ' the asia-pacific', 'south america', 'himalayan', ' atlantic', 'north korea’s', '"asias"', '"south asias t&t"', 'the north east', ' south east asia', 'the huanan seafood market', 'the asia pacific', 'indo-bangladesh', ' euro-asia', 'ecycle valley', ' north-west', ' south asia', 'central america', 'gangetic', 'sub-saharan africa', '"arcelormittals south africa"', 'kg) basin', 'tier 2', 'west texas', 'northeast region', ' asia', 'the mann taluka', 'south asia’s', 'cayman islands', ' far east', 'the indo-pacific', 'the uber elevate asia pacific expo.', 'delhi-national capital region', 'union territories', 'africa', ' southeast asia', '"indian oceans"', ' "indo-pacific"', 'goldilocks', 'tier iii', ' north east india', 'americas', 'indo-pacific', 'east', 'north america’s', '"west bengals"', 'axis', ' north', 'the damodar valley command area', 'asia-pacific & japan', 'oceans', ' south sea', 'nordics', 'the sunshine coast', ' pacific', 'the caspian sea', ' greater noida', 'east asia', ' digha', 'the indian ocean', 'ganges', ' the tropical pacific ocean', 'ganga', 'indian region', 'southeast asia', 'the middle east', 'latin america', ' west asia', ' latin america', ' europe', ' the middle east', 'the delhi-ncr region', ' eurasia', 'covid', 'silicon valley', '"ladakhs galwan valley"', ' asia-pacific japan', 'pacific', ' red zones', 'greater noida', 'mumbai’s lower parel', 'south east asia', ' the bengal basin', 'gulf', 'indo-pacific region', 'kharif', 'the persian gulf', 'australasia', 'rising wedge', 'northeast', 'south asia']
# [' mg capital', ' micron', ' sbi caps', 'rtgs', 'wto', 'telugu desam party', ' inter corporate financiers', ' essel infraprojects', ' cesc', 'bosch', ' wipro', ' quantum amc', ' krbl', ' "bps"', ' ola’s', ' tata communications', '"cms"', 'cbu', ' pmses', ' edge', ' fm', 'lyft', ' gst', ' american eagle', ' demu', ' etihad', ' engineer’s india', 'kreditech', ' eros now', ' senate', 'the indian institute of petroleum', 'reliance power', ' llp', ' medicare', ' icici banks', ' sunrise foods private limited', '"hyundai motor cos indian"', 'the american worker', 'indiabulls securities', 'letsventure', ' puma', ' amazon facebook', 'nintendo', 'bjp’s', ' "lndianoils gujarat refinery"', ' metals', ' hudco', ' myloancare', 'removeincompetentik', 'tesla', ' citi', ' trf', 'arhc', 'bondevalue', 'bsh', 'md & cio', ' devi seafoods', '3one4 capital', '"a smart city mission"', 'sterlite', ' xiaomi', ' "moodys investors service"', ' invesco oppenheimer developing markets fund', 'hdfc mf', 'muthoot finance', ' "bobs"', 'tata consultancy services ltd', 'tata consulting services', 'excise', ' data sciences', ' neogen chemicals', 'dea', 'bnfs', ' icicidirect', ' mg', '"kims"', 'indian railway catering & tourism corporation', ' the emami art', ' "sodexos"', ' rentomojo', 'fsdc', 'reserve bank of india', ' national social security fund', ' ebr/rllr', ' nri', 'india business council', ' dot', ' bpo', 'jis', ' mylab', 'plastone', 'navneet damani', ' dfbl', ' walmart global tech', 'fatf', ' m&m.', 'the paris club', ' lt', ' bajaj allianz life insurance', ' "sp groups"', ' the federal reserve', ' parag milk foods', ' harsha engineers', ' indiabulls real estate', ' hk', 'apple', ' idea cellular', ' cj', ' ev', 'finance commission', ' mlas', 'mnrega', ' gurupurab', ' computer age management services', 'goair', 'the delhi bench', 'tata harrier', 'tcns', 'gjc', ' bfsi', ' redmart', 'castrol', ' mufg bank', ' eko financial services', 'boeing', ' the authorised dealer banks', 'the government of jharkhand', 'ems', ' uco bank', ' obra-c badaun transmission limited', '"taipas"', ' hindustan construction company', 'wrp', ' gsi', 'titan', ' kalpataru power', 'shimamura co', ' cait', 'general electric', ' board of directors', ' "roe winners"', 'lmt', 'ima', ' uti amc', ' magneto cleantech', ' "oneplus"', 'kratikal', ' cic', ' merrill lynch', ' hotel california', ' unicef', 'zydus wellness', ' fca', ' ftse mib', ' yy inc', ' hvs anarock', 'icici prudential life', ' adia', 'hap daily', '"mukesh ambanis jio platforms"', ' limited liability partnerships', 'e-nam', ' mmtc', 'lockheed martin', 'w-gdp', ' tv18 broadcast', ' unified payments interface', 'englishhelpertm', ' sangh', ' phama', ' atma nirbhar bharat', 'avengers', 'avtr', ' icici lombard general insurance', ' obc', ' nbfc', ' ltcm', 'jll', ' pine labs', 'softbank vision fund', 'wns', 'hang seng', 'ndb', 'strategic petroleum reserve', ' jindal steel', 'q1fy21', ' tejas entertainment', 'canararobeco emerging equities fund', ' den networks', ' esc', ' ertiga', 'the cleveland clinic', ' the mann deshi foundation', '"mercers"', ' ayush', ' razorpayx corporate cards', 'bjp', 'ariel', ' national register of citizens', ' bundesliga', ' smid', ' walmart', ' edelweiss', 'indiabulls ventures', 'ed & cio', ' dow', 'cmd', ' epc', ' balrampur chini', 'linkedin influencers on economy and finance', ' alembic pharma', 'irdai', ' tm', 'marashtra', ' start up india', 'brand equity', ' kotak bank', ' ist', ' aifs/reits/invits', 'pan', 'bri', ' s&p global ratings', ' nirmal bang institutional equities', ' nippon india mutual fund', 'redbus', 'sterlite technologies', 'hbn', '"bearish belt hold"', ' genmab', 'pomis', ' egm', 'nsf', 'kremlin', 'covid india', ' agri', ' renault', ' q3', ' bnp', 'infibeam avenues ltd', ' the us centre for disease control', ' bse bankex', 'drhp', ' tvs motor', ' geojit financial services', ' dr lal pathlabs', 'rcom', 'alibaba', 'sbm bank india', 'mintplainfacts', 'elss', '"spxs"', 'cyan', ' walmart inc. ...

# %%
print(f"Number of unique LOC entities: {len(locs)}")
print(f"Number of unique ORG entities: {len(orgs)}")
# Out:
# Number of unique LOC entities: 150
# Number of unique ORG entities: 5622

# %%
indian_entities = pd.read_csv("../../data/output/indian/indian_entities.csv", encoding="utf-8")

# %%
indian_entities = indian_entities[indian_entities["is_india"] == 1]
print(len(indian_entities))
indian_entities.head()
# Out:
# 1974
#                             entity  \
# 0                         Glucon D
# 1                        Kotak Mah
# 2                         Railways
# 3  Hindustan Petroleum Corporation
# 4                             LXME
#
#                                          description  is_india
# 0   Zydus Wellness A popular glucose-based energy...       1.0
# 1  Kotak Mahindra Bank is a leading Indian privat...       1.0
# 2                          Refers to Indian Railways       1.0
# 3  A state-owned oil and natural gas company in I...       1.0
# 4  India’s first financial platform designed for ...       1.0

# %%
ents = indian_entities["entity"].values
ents = [ent.lower() for ent in ents]

org_indices = df[df["ORG"].apply(lambda x: any(ent in x for ent in ents) if pd.notna(x) else False)].index
print(org_indices)
# Out:
# Index([    1,     7,     8,    10,    13,    16,    17,    19,    21,    26,
#        ...
#        26887, 26888, 26889, 26890, 26891, 26892, 26893, 26896, 26897, 26899],
#       dtype='int64', length=11408)

# %%
len(org_indices)
# Out:
# 11408

# %%
predictions = pd.read_csv("../../data/output/indian/predictions.csv", encoding="utf-8")
predictions.head()
# Out:
#      y_true    y_pred
# 0  Negative  Negative
# 1  Negative   Neutral
# 2  Negative  Negative
# 3  Negative  Negative
# 4  Negative   Neutral

# %%
indian_predictions = predictions.loc[org_indices]
other_predictions = predictions.drop(org_indices)

# %%
print(len(indian_predictions))
print(len(other_predictions))

# create a new prediction df with a new column "is_india" and include all predictions
indian_predictions["is_india"] = 1
other_predictions["is_india"] = 0
pred_df = pd.concat([indian_predictions, other_predictions])
# Out:
# 11408
# 15553

# %%
pred_df.head()
# Out:
#       y_true    y_pred  is_india
# 1   Negative   Neutral         1
# 7   Negative  Negative         1
# 8   Negative  Negative         1
# 10  Negative  Negative         1
# 13  Negative  Positive         1

# %%
pred_df.tail()
# Out:
#          y_true    y_pred  is_india
# 26956  Positive  Positive         0
# 26957  Positive  Positive         0
# 26958  Positive  Positive         0
# 26959  Positive  Positive         0
# 26960  Positive   Neutral         0

# %%
from fairlearn.metrics import MetricFrame
from fairlearn.metrics import count, \
                              false_positive_rate, \
                              selection_rate
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import matplotlib.pyplot as plt

# %%
y_true = pred_df["y_true"].map({"Positive": 1, "Negative": -1})
y_pred = pred_df["y_pred"].map({"Positive": 1, "Negative":-1})
sf_data = pred_df["is_india"]

# %%
nan_locations = y_pred[y_pred.isna()].index
y_pred = y_pred.drop(nan_locations)
y_true = y_true.drop(nan_locations)
sf_data = sf_data.drop(nan_locations)

nan_locations = y_true[y_true.isna()].index
y_pred = y_pred.drop(nan_locations)
y_true = y_true.drop(nan_locations)
sf_data = sf_data.drop(nan_locations)

cm = confusion_matrix(y_true, y_pred, labels=[1,-1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Positive", "Negative"])
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix for Positive and Negative')
plt.show()

# %%
# Define a custom recall function with average='macro' and pos_label='positive'
def recall_macro(y_true, y_pred):
    return recall_score(y_true, y_pred, average='macro')

# Construct a function dictionary
my_metrics = {
    'tpr' : recall_macro,
    'fpr' : false_positive_rate,
    'sel' : selection_rate,
    'count' : count
}

# Construct a MetricFrame
mf = MetricFrame(
    metrics=my_metrics,
    y_true=y_true,
    y_pred=y_pred,
    sensitive_features=sf_data,
)

# %%
mf.overall
# Out:
# tpr          0.872276
# fpr          0.180402
# sel          0.532981
# count    11340.000000
# dtype: float64

# %%
mf.by_group
# Out:
#                tpr       fpr       sel   count
# is_india
# 0         0.865665  0.188157  0.494186  6708.0
# 1         0.882580  0.165781  0.589162  4632.0

# %%
from fairlearn.metrics import demographic_parity_ratio
from fairlearn.metrics import equalized_odds_ratio

# %%
print(mf.group_min())
# Out:
# tpr      0.865665
# fpr      0.165781
# sel      0.494186
# count      4632.0
# dtype: object

# %%
print(mf.group_max())
# Out:
# tpr       0.88258
# fpr      0.188157
# sel      0.589162
# count      6708.0
# dtype: object

# %%
print(mf.difference())
# Out:
# tpr         0.016915
# fpr         0.022376
# sel         0.094976
# count    2076.000000
# dtype: float64

# %%
print(mf.ratio())
# Out:
# tpr      0.980835
# fpr      0.881076
# sel      0.838794
# count    0.690519
# dtype: float64

# %%
print(mf.difference(method='to_overall'))
# Out:
# tpr         0.010304
# fpr         0.014621
# sel         0.056182
# count    6708.000000
# dtype: float64

# %%
print(mf.ratio(method='to_overall'))
# Out:
# tpr      0.988325
# fpr      0.918951
# sel      0.904641
# count    0.408466
# dtype: float64

# %%
print(demographic_parity_ratio(y_true,
                               y_pred,
                               sensitive_features=sf_data))
# Out:
# 0.8387943449768636

# %%
print(equalized_odds_ratio(y_true,
                               y_pred,
                               sensitive_features=sf_data))
# Out:
# 0.8810763008627422

# %%
print(min(mf.ratio(method="between_groups")))
# Out:
# 0.6905187835420393
